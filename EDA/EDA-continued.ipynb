# %% [markdown]
# ## Exploratory Data Anlysis
#
# ### Identifiers
# - SUBJECT_ID: identifiers to a unique patient
# - HADM_ID: identifiers to an admission to hospital
# - ICUSTAY_ID: identifiers to a unique admission to intensive care unit
#
# ### Charted events
# - OUTPUT events table contains all measurements related to output for a given patient.

# %% [markdown]
# ### Create the primary outcome variable
# - The length of stay is the time from the admission to the discharge from hospital.
# - The data contains protected health information so the actual admission time and discharge time are shifted.
# - The distribution of the outcome variable is highly skewed.
#     - Dichotomize the outcome variable (imbalanced classification problem).
#     - Keep the continuous variable and find optimal methods to model skewed distribution.

# %% [markdown]
# ### Discharge Location
# - Most of the patients are discharged to home/home health care/hospice-home/home with home IV provider.
# - Some of the patients are discharged to SNF (Skilled Nursing Facility). It can also be a secondary outcome variable.
# - Some of the patients are discharged to hospice-medical facility.
#
# **Note:**
# - Home Health Care: Home health care is a wide range of health care services that can be given in your home for an illness or injury. Home health care is usually less expensive, more convenient, and just as effective as care you get in a hospital or skilled nursing facility (SNF). References: https://www.medicare.gov/what-medicare-covers/whats-home-health-care
# - Long term care hospital: Most patients who need to be in intensive care for an extended time are often transferred to a long-term care hospital to continue that care.

# %% [markdown]
# ### Potential predictors
# #### Demographical Data
# - Insurance type, Language, ethnicity, marital_status, age, sex
#
# #### Diagnosis
# - Diagnosis variable contains too many levels.
#     - Delete some levels with too less patients.
#     - Combine some levels, such as diagnosis starting with nausea and subtypes of coronary artery disease.
# - After combining the patients table with the admission table, there is no missing data.
#
# #### Vitals

# %% [markdown]
# ### DRG codes
# - The diagnosis-related group codes is a system to classify hospital cases into one of 467 cases.

# %% [markdown]
# According to [physionet tutorial](https://physionet.org/content/mimiciii/1.4/), all the observations who are older than 89 years old will be assigned a fake age. Here, I converted all the observations who are older than 89 years old to 89.

# %% [markdown]
# ________________________________________

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/processed_data1.csv')

# %%
df = df.drop('Unnamed: 0', axis=1)
df = df.drop('ROW_ID', axis=1)

# %%
df
# Out:
#        SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0               2   163353  2138-07-17 19:04:00  2138-07-21 15:48:00
# 1               3   145834  2101-10-20 19:08:00  2101-10-31 13:58:00
# 2               4   185777  2191-03-16 00:28:00  2191-03-23 18:41:00
# 3               5   178980  2103-02-02 04:31:00  2103-02-04 12:15:00
# 4               6   107064  2175-05-30 07:15:00  2175-06-15 16:00:00
# ...           ...      ...                  ...                  ...
# 46515       99985   176670  2181-01-27 02:47:00  2181-02-12 17:05:00
# 46516       99991   151118  2184-12-24 08:30:00  2185-01-05 12:15:00
# 46517       99992   197084  2144-07-25 18:03:00  2144-07-28 17:56:00
# 46518       99995   137810  2147-02-08 08:00:00  2147-02-11 13:15:00
# 46519       99999   113369  2117-12-30 07:15:00  2118-01-04 16:30:00
#
#       DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0           NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 1           NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 2           NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 3           NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 4           NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# ...         ...            ...                        ...
# 46515       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 46516       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 46517       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 46518       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 46519       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
#
#               DISCHARGE_LOCATION INSURANCE LANGUAGE  ...               INTIME  \
# 0                           HOME   Private      NaN  ...  2138-07-17T21:20:07
# 1                            SNF  Medicare      NaN  ...  2101-10-20T19:10:11
# 2      HOME WITH HOME IV PROVIDR   Private      NaN  ...  2191-03-16T00:29:31
# 3                           HOME   Private      NaN  ...  2103-02-02T06:04:24
# 4               HOME HEALTH CARE  Medicare     ENGL  ...  2175-05-30T21:30:54
# ...                          ...       ...      ...  ...                  ...
# 46515           HOME HEALTH CARE   Private     ENGL  ...  2181-01-29T05:33:34
# 46516                       HOME   Private     ENGL  ...  2184-12-28T17:30:58
# 46517                        SNF  Medicare     ENGL  ...  2144-07-25T18:04:42
# 46518                       HOME  Medicare     ENGL  ...  2147-02-08T13:53:58
# 46519                        SNF  Medicare     SPAN  ...  2117-12-31T11:52:36
#
#                    OUTTIME  ICU_LOS  Height Weight GENDER  \
# 0      2138-07-17T23:32:21   0.0918     NaN    NaN      M
# 1      2101-10-26T20:43:09   6.0646  179.07   96.8      M
# 2      2191-03-17T16:46:31   1.6785     NaN   53.6      F
# 3      2103-02-02T08:06:00   0.0844     NaN    NaN      M
# 4      2175-06-03T13:39:54   3.6729     NaN    NaN      F
# ...                    ...      ...     ...    ...    ...
# 46515  2181-02-09T12:45:20  11.2998     NaN    NaN      M
# 46516  2184-12-31T20:56:20   3.1426     NaN  100.5      M
# 46517  2144-07-27T17:27:55   1.9745     NaN   65.4      F
# 46518  2147-02-10T17:46:30   2.1615  159.00   68.0      F
# 46519  2118-01-01T14:51:27   1.1242  152.00   96.5      F
#
#                        DOB                  DOD                    Hosp_LOS  \
# 0      2138-07-17 00:00:00                  NaN   3 days 20:44:00.000000000
# 1      2025-04-11 00:00:00  2102-06-14T00:00:00  10 days 18:50:00.000000000
# 2      2143-05-12 00:00:00                  NaN   7 days 18:13:00.000000000
# 3      2103-02-02 00:00:00                  NaN   2 days 07:44:00.000000000
# 4      2109-06-21 00:00:00                  NaN  16 days 08:45:00.000000000
# ...                    ...                  ...                         ...
# 46515  2127-04-08 00:00:00                  NaN  16 days 14:18:00.000000000
# 46516  2137-04-07 00:00:00                  NaN  12 days 03:45:00.000000000
# 46517  2078-10-17 00:00:00                  NaN   2 days 23:53:00.000000000
# 46518  2058-05-29 00:00:00  2147-09-29T00:00:00   3 days 05:15:00.000000000
# 46519  2054-01-06 00:00:00                  NaN   5 days 09:15:00.000000000
#
#        age
# 0        0
# 1       76
# 2       48
# 3        0
# 4       66
# ...    ...
# 46515   54
# 46516   47
# 46517   66
# 46518   89
# 46519   63
#
# [46520 rows x 46 columns]

# %%
np.sum(df['SUBJECT_ID'].value_counts() != 1)
# Out:
# 0

# %%
df.dtypes
# Out:
# SUBJECT_ID                int64
# HADM_ID                   int64
# ADMITTIME                object
# DISCHTIME                object
# DEATHTIME                object
# ADMISSION_TYPE           object
# ADMISSION_LOCATION       object
# DISCHARGE_LOCATION       object
# INSURANCE                object
# LANGUAGE                 object
# RELIGION                 object
# MARITAL_STATUS           object
# ETHNICITY                object
# EDREGTIME                object
# EDOUTTIME                object
# DIAGNOSIS                object
# HOSPITAL_EXPIRE_FLAG      int64
# HAS_CHARTEVENTS_DATA      int64
# HeartRate_Min           float64
# HeartRate_Max           float64
# HeartRate_Mean          float64
# SysBP_Min               float64
# SysBP_Max               float64
# SysBP_Mean              float64
# DiasBP_Min              float64
# DiasBP_Max              float64
# DiasBP_Mean             float64
# TempC_Max               float64
# RespRate_Max            float64
# RespRate_Mean           float64
# HeartRate_Mean_1        float64
# HeartRate_Min_1         float64
# Glucose_Max             float64
# Glucose_Min             float64
# Glucose_Mean            float64
# icustay_id              float64
# INTIME                   object
# OUTTIME                  object
# ICU_LOS                 float64
# Height                  float64
# Weight                  float64
# GENDER                   object
# DOB                      object
# DOD                      object
# Hosp_LOS                 object
# age                       int64
# dtype: object

# %%
len(df['DIAGNOSIS'].value_counts())
# Out:
# 12607

# %%
df['HeartRate_Min']
# Out:
# 0        140.0
# 1         75.0
# 2         74.0
# 3          NaN
# 4         76.0
#          ...
# 46515     74.0
# 46516     91.0
# 46517     60.0
# 46518     49.0
# 46519     78.0
# Name: HeartRate_Min, Length: 46520, dtype: float64

# %% [markdown]
# ## Correlation

# %%
df_new = df.drop(['SUBJECT_ID', 'HADM_ID'], axis=1)
df_new.corr()
# Out:
#                       HOSPITAL_EXPIRE_FLAG  HAS_CHARTEVENTS_DATA  \
# HOSPITAL_EXPIRE_FLAG              1.000000              0.039791
# HAS_CHARTEVENTS_DATA              0.039791              1.000000
# HeartRate_Min                    -0.094340                   NaN
# HeartRate_Max                     0.021636                   NaN
# HeartRate_Mean                   -0.026477                   NaN
# SysBP_Min                        -0.199091                   NaN
# SysBP_Max                        -0.003180                   NaN
# SysBP_Mean                       -0.113825                   NaN
# DiasBP_Min                       -0.155743                   NaN
# DiasBP_Max                       -0.004643                   NaN
# DiasBP_Mean                      -0.095404                   NaN
# TempC_Max                        -0.022124                   NaN
# RespRate_Max                      0.135957                   NaN
# RespRate_Mean                     0.194074                   NaN
# HeartRate_Mean_1                 -0.026477                   NaN
# HeartRate_Min_1                  -0.094340                   NaN
# Glucose_Max                       0.000306                   NaN
# Glucose_Min                       0.112074                   NaN
# Glucose_Mean                      0.007575                   NaN
# icustay_id                       -0.002174             -0.000480
# ICU_LOS                           0.024218              0.017055
# Height                           -0.040363              0.000673
# Weight                           -0.061062              0.000244
# age                               0.185233             -0.020156
#
#                       HeartRate_Min  HeartRate_Max  HeartRate_Mean  SysBP_Min  \
# HOSPITAL_EXPIRE_FLAG      -0.094340       0.021636       -0.026477  -0.199091
# HAS_CHARTEVENTS_DATA            NaN            NaN             NaN        NaN
# HeartRate_Min              1.000000       0.769227        0.934514   0.016643
# HeartRate_Max              0.769227       1.000000        0.905678  -0.162068
# HeartRate_Mean             0.934514       0.905678        1.000000  -0.110468
# SysBP_Min                  0.016643      -0.162068       -0.110468   1.000000
# SysBP_Max                 -0.098277       0.042769       -0.043447   0.319046
# SysBP_Mean                -0.063177      -0.087142       -0.102403   0.743117
# DiasBP_Min                 0.152474       0.029541        0.093570   0.544952
# DiasBP_Max                 0.064184       0.186637        0.131375   0.170438
# DiasBP_Mean                0.176610       0.172136        0.193277   0.447826
# TempC_Max                  0.236799       0.269471        0.292431  -0.055447
# RespRate_Max               0.219923       0.302570        0.305628  -0.129147
# RespRate_Mean              0.270941       0.291368        0.330383  -0.037623
# HeartRate_Mean_1           0.934514       0.905678        1.000000  -0.110468
# HeartRate_Min_1            1.000000       0.769227        0.934514   0.016643
# Glucose_Max               -0.009288      -0.004493       -0.007778  -0.002894
# Glucose_Min               -0.132156      -0.051748       -0.103479   0.078657
# Glucose_Mean              -0.017269      -0.006641       -0.013083  -0.003539
# icustay_id                -0.002164      -0.002317       -0.001725   0.008767
# ICU_LOS                    0.227665       0.290830        0.270255  -0.102206
# Height                     0.000393      -0.023418       -0.010141   0.029536
# Weight                     0.047394      -0.005984        0.028596   0.037662
# age                       -0.712567      -0.623271       -0.714095  -0.131625
#
#                       SysBP_Max  SysBP_Mean  DiasBP_Min  DiasBP_Max  ...  \
# HOSPITAL_EXPIRE_FLAG  -0.003180   -0.113825   -0.155743   -0.004643  ...
# HAS_CHARTEVENTS_DATA        NaN         NaN         NaN         NaN  ...
# HeartRate_Min         -0.098277   -0.063177    0.152474    0.064184  ...
# HeartRate_Max          0.042769   -0.087142    0.029541    0.186637  ...
# HeartRate_Mean        -0.043447   -0.102403    0.093570    0.131375  ...
# SysBP_Min              0.319046    0.743117    0.544952    0.170438  ...
# SysBP_Max              1.000000    0.745131    0.142468    0.504979  ...
# SysBP_Mean             0.745131    1.000000    0.409560    0.382058  ...
# DiasBP_Min             0.142468    0.409560    1.000000    0.287293  ...
# DiasBP_Max             0.504979    0.382058    0.287293    1.000000  ...
# DiasBP_Mean            0.344705    0.523644    0.765236    0.623632  ...
# TempC_Max              0.089888    0.007407   -0.004969    0.007361  ...
# RespRate_Max           0.030256   -0.069750   -0.083678    0.072821  ...
# RespRate_Mean         -0.024407   -0.033791   -0.053391    0.077611  ...
# HeartRate_Mean_1      -0.043447   -0.102403    0.093570    0.131375  ...
# HeartRate_Min_1       -0.098277   -0.063177    0.152474    0.064184  ...
# Glucose_Max            0.012980    0.001658   -0.004299    0.002558  ...
# Glucose_Min            0.051855    0.099509    0.029177    0.074082  ...
# Glucose_Mean           0.016799    0.004327   -0.005917    0.004533  ...
# icustay_id             0.001734    0.005420    0.008619    0.005860  ...
# ICU_LOS                0.072462   -0.029253   -0.056817    0.023929  ...
# Height                -0.025801    0.000465    0.120198    0.010870  ...
# Weight                 0.022970    0.036976    0.074982    0.051855  ...
# age                    0.115947    0.006108   -0.305714   -0.095927  ...
#
#                       HeartRate_Mean_1  HeartRate_Min_1  Glucose_Max  \
# HOSPITAL_EXPIRE_FLAG         -0.026477        -0.094340     0.000306
# HAS_CHARTEVENTS_DATA               NaN              NaN          NaN
# HeartRate_Min                 0.934514         1.000000    -0.009288
# HeartRate_Max                 0.905678         0.769227    -0.004493
# HeartRate_Mean                1.000000         0.934514    -0.007778
# SysBP_Min                    -0.110468         0.016643    -0.002894
# SysBP_Max                    -0.043447        -0.098277     0.012980
# SysBP_Mean                   -0.102403        -0.063177     0.001658
# DiasBP_Min                    0.093570         0.152474    -0.004299
# DiasBP_Max                    0.131375         0.064184     0.002558
# DiasBP_Mean                   0.193277         0.176610    -0.006897
# TempC_Max                     0.292431         0.236799    -0.003030
# RespRate_Max                  0.305628         0.219923     0.008888
# RespRate_Mean                 0.330383         0.270941     0.000861
# HeartRate_Mean_1              1.000000         0.934514    -0.007778
# HeartRate_Min_1               0.934514         1.000000    -0.009288
# Glucose_Max                  -0.007778        -0.009288     1.000000
# Glucose_Min                  -0.103479        -0.132156     0.004895
# Glucose_Mean                 -0.013083        -0.017269     0.998844
# icustay_id                   -0.001725        -0.002164     0.007561
# ICU_LOS                       0.270255         0.227665     0.008182
# Height                       -0.010141         0.000393    -0.015328
# Weight                        0.028596         0.047394     0.059052
# age                          -0.714095        -0.712567     0.006015
#
#                       Glucose_Min  Glucose_Mean  icustay_id   ICU_LOS  \
# HOSPITAL_EXPIRE_FLAG     0.112074      0.007575   -0.002174  0.024218
# HAS_CHARTEVENTS_DATA          NaN           NaN   -0.000480  0.017055
# HeartRate_Min           -0.132156     -0.017269   -0.002164  0.227665
# HeartRate_Max           -0.051748     -0.006641   -0.002317  0.290830
# HeartRate_Mean          -0.103479     -0.013083   -0.001725  0.270255
# SysBP_Min                0.078657     -0.003539    0.008767 -0.102206
# SysBP_Max                0.051855      0.016799    0.001734  0.072462
# SysBP_Mean               0.099509      0.004327    0.005420 -0.029253
# DiasBP_Min               0.029177     -0.005917    0.008619 -0.056817
# DiasBP_Max               0.074082      0.004533    0.005860  0.023929
# DiasBP_Mean              0.076764     -0.006486    0.005501 -0.031412
# TempC_Max               -0.071605     -0.004571   -0.000941  0.148418
# RespRate_Max            -0.001250      0.010874   -0.003919  0.107267
# RespRate_Mean            0.086320      0.004867   -0.002935  0.104334
# HeartRate_Mean_1        -0.103479     -0.013083   -0.001725  0.270255
# HeartRate_Min_1         -0.132156     -0.017269   -0.002164  0.227665
# Glucose_Max              0.004895      0.998844    0.007561  0.008182
# Glucose_Min              1.000000      0.042330   -0.003827  0.009842
# Glucose_Mean             0.042330      1.000000    0.007216  0.010984
# icustay_id              -0.003827      0.007216    1.000000  0.004294
# ICU_LOS                  0.009842      0.010984    0.004294  1.000000
# Height                   0.013809     -0.004068    0.005954 -0.000575
# Weight                   0.079686      0.092937    0.004183  0.041429
# age                      0.160169      0.017045    0.005963 -0.176285
#
#                         Height    Weight       age
# HOSPITAL_EXPIRE_FLAG -0.040363 -0.061062  0.185233
# HAS_CHARTEVENTS_DATA  0.000673  0.000244 -0.020156
# HeartRate_Min         0.000393  0.047394 -0.712567
# HeartRate_Max        -0.023418 -0.005984 -0.623271
# HeartRate_Mean       -0.010141  0.028596 -0.714095
# SysBP_Min             0.029536  0.037662 -0.131625
# SysBP_Max            -0.025801  0.022970  0.115947
# SysBP_Mean            0.000465  0.036976  0.006108
# DiasBP_Min            0.120198  0.074982 -0.305714
# DiasBP_Max            0.010870  0.051855 -0.095927
# DiasBP_Mean           0.113932  0.104151 -0.340395
# TempC_Max             0.049772  0.057115 -0.154620
# RespRate_Max         -0.026366  0.013446  0.022172
# RespRate_Mean        -0.023733  0.033530  0.034914
# HeartRate_Mean_1     -0.010141  0.028596 -0.714095
# HeartRate_Min_1       0.000393  0.047394 -0.712567
# Glucose_Max          -0.015328  0.059052  0.006015
# Glucose_Min           0.013809  0.079686  0.160169
# Glucose_Mean         -0.004068  0.092937  0.017045
# icustay_id            0.005954  0.004183  0.005963
# ICU_LOS              -0.000575  0.041429 -0.176285
# Height                1.000000  0.317113 -0.168359
# Weight                0.317113  1.000000 -0.182386
# age                  -0.168359 -0.182386  1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# ## added variable plots

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#prestige_model = ols("prestige ~ income + education", data=prestige).fit()

# %%
#fig = sm.graphics.plot_partregress_grid(prestige_model)
#fig.tight_layout(pad=1.0)

# %%
#fig = sm.graphics.plot_partregress("prestige", "income", ["income", "education"], data=prestige)
#fig.tight_layout(pad=1.0)
